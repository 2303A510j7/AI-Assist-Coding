# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510j7/AI-Assist-Coding/blob/main/AI_Assist_coding_Lab_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Task 1: Cleaning Sensor** **Data**

# %% [markdown]
# ### #Use Gemini in Google Colab to generate a Python function that filters out all negative numbers from a list of sensor readings.

# %%
def remove_negative_values(sensor_data):
    cleaned_data = []
    for value in sensor_data:
        if value >= 0:
            cleaned_data.append(value)
    return cleaned_data

# Sample IoT sensor data
sensor_data = [12, -5, 8, -3, 0, 15, -10]

print("Before cleaning:", sensor_data)
print("After cleaning:", remove_negative_values(sensor_data))
# Out:
# Before cleaning: [12, -5, 8, -3, 0, 15, -10]
# After cleaning: [12, 8, 0, 15]

# %%
from IPython.display import Image, display

display(Image(filename='/content/image.png'))

# %% [markdown]
# ### Explanation:The function removes all negative values from IoT sensor data to ensure only valid sensor readings are used.

# %% [markdown]
# # **Task 2:String Character Analysis**

# %% [markdown]
# ### #Use Gemini to generate a Python function that counts vowels, consonants,and digits in a string.

# %%
def count_characters(text):
    vowels = "aeiouAEIOU"
    vowel_count = 0
    consonant_count = 0
    digit_count = 0

    for ch in text:
        if ch.isdigit():
            digit_count += 1
        elif ch.isalpha():
            if ch in vowels:
                vowel_count += 1
            else:
                consonant_count += 1

    return vowel_count, consonant_count, digit_count

# %% [markdown]
# ### sample input & output:

# %%
text = "Hello123World"

vowels, consonants, digits = count_characters(text)

print("String:", text)
print("Vowels:", vowels)
print("Consonants:", consonants)
print("Digits:", digits)
# Out:
# String: Hello123World
# Vowels: 3
# Consonants: 7
# Digits: 3

# %%
from IPython.display import Image, display

display(Image(filename='/content/image1.png'))

# %% [markdown]
# ### Explantion:The function counts vowels, consonants, and digits in a string by checking each character individually

# %% [markdown]
# # **Task 3:Palindrome Check-Tool Comparison**

# %% [markdown]
# ### #Generate a Python function to check whether a given string is a palindrome.

# %% [markdown]
# Code generated by Gemini:

# %%
def is_palindrome(text):
    text = text.lower()
    reversed_text = text[::-1]
    return text == reversed_text

# %% [markdown]
# Code generated by Copilot:

# %%
def is_palindrome(text):
    cleaned = ''.join(char.lower() for char in text if char.isalnum())
    left = 0
    right = len(cleaned) - 1
    while left < right:
        if cleaned[left] != cleaned[right]:
            return False
        left += 1
        right -= 1
    return True

# %% [markdown]
# Output:

# %% [markdown]
# | Feature                    | Gemini                  | Copilot                 |
# | -------------------------- | ----------------------- | ----------------------- |
# | Code Length                | Short                   | Longer                  |
# | Logic                      | Uses string reverse     | Uses two-pointer method |
# | Readability                | Very easy to understand | Slightly complex        |
# | Beginner Friendly          | Yes                   |  Moderate             |
# | Handles special characters |  No                    | Yes                   |

# %% [markdown]
# Observation:Gemini provides a clear and beginner-friendly solution, whereas Copilot provides a more comprehensive and real-world–oriented solution.

# %% [markdown]
# # **Task 4:Code Explanation Using AI**

# %% [markdown]
# ### #Explain the following Python palindrome-checking function line by line in simple terms

# %% [markdown]
# Code snippet:

# %%
def is_palindrome(text):
    text = text.lower()
    reversed_text = text[::-1]
    return text == reversed_text

# %% [markdown]
# AI Explanation:

# %% [markdown]
# def is_palindrome(text):
# Defines a function named is_palindrome that takes a string as input.
#
# text = text.lower()
# Converts the string to lowercase so that uppercase and lowercase letters are treated the same.
#
# reversed_text = text[::-1]
# Reverses the string using Python slicing.
#
# return text == reversed_text
#
# Compares the original string with the reversed string and returns True if they are the same, otherwise False.

# %% [markdown]
# **Observation:**
# The Gemini explanation helped me understand the palindrome function quickly. It converts the string to lowercase, reverses it using slicing, and compares it to the original to check if it is a palindrome. This made it easy to follow each line and understand how the function works.
